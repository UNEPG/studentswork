# %%
ls
# Out:
#  hello.dio   laura1.txt       shared           'Untitled Folder'
#  laura      'my work.ipynb'   Untitled1.ipynb   Untitled.ipynb

# %%
file laura1.txt
# Out:
# laura1.txt: ASCII text

# %%
touch helloworld.txt

# %%
ls
# Out:
#  hello.dio        laura1.txt       Untitled1.ipynb
#  helloworld.txt  'my work.ipynb'  'Untitled Folder'
#  laura            shared           Untitled.ipynb

# %%
echo 'Unisat'>unisatt

# %%
ls
# Out:
#  hello.dio        laura1.txt       unisatt            Untitled.ipynb
#  helloworld.txt  'my work.ipynb'   Untitled1.ipynb
#  laura            shared          'Untitled Folder'

# %%
file unisatt
# Out:
# unisatt: ASCII text

# %%
file lau.mp3
# Out:
# lau.mp3: cannot open `lau.mp3' (No such file or directory)

# %%
cd

# %%
pwd
# Out:
# /home/jupyter-nurlaura2

# %%
cd laura

# %%
pwd
# Out:
# /home/jupyter-nurlaura2/laura

# %%
cd ..

# %%
pwd
# Out:
# /home/jupyter-nurlaura2

# %%
ls
# Out:
#  hello.dio        laura1.txt       unisatt            Untitled.ipynb
#  helloworld.txt  'my work.ipynb'   Untitled1.ipynb
#  laura            shared          'Untitled Folder'

# %%
ls -a
# Out:
#  .               hello.dio            laura1.txt       Untitled1.ipynb
#  ..              helloworld.txt       .local          'Untitled Folder'
#  .bash_history   .ipynb_checkpoints  'my work.ipynb'   Untitled.ipynb
#  .bash_logout    .ipython             .profile
#  .bashrc         .jupyter             shared
#  .cache          laura                unisatt

# %%
ls -l
# Out:
# total 32
# -rw-r--r-- 1 jupyter-nurlaura2 jupyter-nurlaura2  435 Mar 28 00:39  hello.dio
# -rw-r--r-- 1 jupyter-nurlaura2 jupyter-nurlaura2    0 Mar 28 00:48  helloworld.txt
# drwxr-xr-x 2 jupyter-nurlaura2 jupyter-nurlaura2 4096 Mar 28 00:30  laura
# -rw-r--r-- 1 jupyter-nurlaura2 jupyter-nurlaura2   13 Mar 28 00:36  laura1.txt
# -rw-r--r-- 1 jupyter-nurlaura2 jupyter-nurlaura2 4081 Mar 28 00:54 'my work.ipynb'
# lrwxrwxrwx 1 jupyter-nurlaura2 jupyter-nurlaura2   16 Mar 10 11:57  shared -> /srv/data/shared
# -rw-r--r-- 1 jupyter-nurlaura2 jupyter-nurlaura2    7 Mar 28 00:49  unisatt
# -rw-r--r-- 1 jupyter-nurlaura2 jupyter-nurlaura2  410 Mar 28 00:33  Untitled1.ipynb
# drwxr-xr-x 2 jupyter-nurlaura2 jupyter-nurlaura2 4096 Mar 28 00:36 'Untitled Folder'
# -rw-r--r-- 1 jupyter-nurlaura2 jupyter-nurlaura2 1196 Mar 28 00:33  Untitled.ipynb

# %%
man ls
# Out:
# LS(1)                            User Commands                           LS(1)
#
# NAME
#        ls - list directory contents
#
# SYNOPSIS
#        ls [OPTION]... [FILE]...
#
# DESCRIPTION
#        List  information  about  the FILEs (the current directory by default).
#        Sort entries alphabetically if none of -cftuvSUX nor --sort  is  speci‐
#        fied.
#
#        Mandatory  arguments  to  long  options are mandatory for short options
#        too.
#
#        -a, --all
#               do not ignore entries starting with .
#
#        -A, --almost-all
#               do not list implied . and ..
#
#        --author
#               with -l, print the author of each file
#
#        -b, --escape
#               print C-style escapes for nongraphic characters
#
#        --block-size=SIZE
#               scale sizes by SIZE before printing them; e.g., '--block-size=M'
#               prints sizes in units of 1,048,576 bytes; see SIZE format below
#
#        -B, --ignore-backups
# ...
