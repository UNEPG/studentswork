# %%
ls
# Out:
# resume.txt  Untitled1.ipynb  Untitled2.ipynb  Untitled.ipynb

# %%
file resume.txt
# Out:
# resume.txt: empty

# %%
touch orissim.txt

# %%
ls
# Out:
# orissim.txt  resume.txt  Untitled1.ipynb  Untitled2.ipynb  Untitled.ipynb

# %%
echo 'UniSat'>UniSat

# %%
file UniSat
# Out:
# UniSat: ASCII text

# %%
cd

# %%
pwd
# Out:
# /home/jupyter-orissim

# %%
cd orissim

# %%
pwd
# Out:
# /home/jupyter-orissim/orissim

# %%
ls -l
# Out:
# total 16
# -rw-r--r-- 1 jupyter-orissim jupyter-orissim    0 Mar 28 01:59 orissim.txt
# -rw-r--r-- 1 jupyter-orissim jupyter-orissim    0 Mar 28 01:54 resume.txt
# -rw-r--r-- 1 jupyter-orissim jupyter-orissim    7 Mar 28 01:59 UniSat
# -rw-r--r-- 1 jupyter-orissim jupyter-orissim 2105 Mar 28 01:56 Untitled1.ipynb
# -rw-r--r-- 1 jupyter-orissim jupyter-orissim 2546 Mar 28 02:00 Untitled2.ipynb
# -rw-r--r-- 1 jupyter-orissim jupyter-orissim   72 Mar 28 01:54 Untitled.ipynb

# %%
ls -a
# Out:
# .   .ipynb_checkpoints  resume.txt  Untitled1.ipynb  Untitled.ipynb
# ..  orissim.txt         UniSat      Untitled2.ipynb

# %%
ls -a -l
# Out:
# total 28
# drwxr-xr-x 3 jupyter-orissim jupyter-orissim 4096 Mar 28 02:00 .
# drwxr-x--- 8 jupyter-orissim jupyter-orissim 4096 Mar 28 01:54 ..
# drwxr-xr-x 2 jupyter-orissim jupyter-orissim 4096 Mar 28 01:58 .ipynb_checkpoints
# -rw-r--r-- 1 jupyter-orissim jupyter-orissim    0 Mar 28 01:59 orissim.txt
# -rw-r--r-- 1 jupyter-orissim jupyter-orissim    0 Mar 28 01:54 resume.txt
# -rw-r--r-- 1 jupyter-orissim jupyter-orissim    7 Mar 28 01:59 UniSat
# -rw-r--r-- 1 jupyter-orissim jupyter-orissim 2105 Mar 28 01:56 Untitled1.ipynb
# -rw-r--r-- 1 jupyter-orissim jupyter-orissim 2546 Mar 28 02:00 Untitled2.ipynb
# -rw-r--r-- 1 jupyter-orissim jupyter-orissim   72 Mar 28 01:54 Untitled.ipynb

# %%
man ls
# Out:
# LS(1)                            User Commands                           LS(1)
#
# NAME
#        ls - list directory contents
#
# SYNOPSIS
#        ls [OPTION]... [FILE]...
#
# DESCRIPTION
#        List  information  about  the FILEs (the current directory by default).
#        Sort entries alphabetically if none of -cftuvSUX nor --sort  is  speci‐
#        fied.
#
#        Mandatory  arguments  to  long  options are mandatory for short options
#        too.
#
#        -a, --all
#               do not ignore entries starting with .
#
#        -A, --almost-all
#               do not list implied . and ..
#
#        --author
#               with -l, print the author of each file
#
#        -b, --escape
#               print C-style escapes for nongraphic characters
#
#        --block-size=SIZE
#               scale sizes by SIZE before printing them; e.g., '--block-size=M'
#               prints sizes in units of 1,048,576 bytes; see SIZE format below
#
#        -B, --ignore-backups
# ...
