# %%
pwd
# Out:
# /home/jupyter-inkar601

# %%
ls
# Out:
# 222.ipynb  inkar_hw4.ipynb   shared            Untitled6.ipynb
# 444.ipynb  Inkar.ipynb       Untitled10.ipynb  Untitled7.ipynb
# bear       inkar.txt         Untitled11.ipynb  Untitled8.ipynb
# Donut      octave-workspace  Untitled1.ipynb   Untitled9.ipynb
# donut.txt  pulsar            Untitled2.ipynb   Untitled.ipynb
# homework1  pulsar.txt        Untitled3.ipynb
# homework3  river.ipynb       Untitled4.ipynb
# inkar      river.txt         Untitled5.ipynb

# %%
ls -l
# Out:
# total 244
# -rw-r--r-- 1 jupyter-inkar601 jupyter-inkar601 48435 Mar 28 13:24 222.ipynb
# -rw-r--r-- 1 jupyter-inkar601 jupyter-inkar601  4846 Apr  4 12:15 444.ipynb
# -rw-r--r-- 1 jupyter-inkar601 jupyter-inkar601     0 Apr  4 12:09 bear
# drwxr-xr-x 2 jupyter-inkar601 jupyter-inkar601  4096 Mar 28 13:06 Donut
# -rw-r--r-- 1 jupyter-inkar601 jupyter-inkar601    13 Mar 28 02:00 donut.txt
# drwxr-xr-x 3 jupyter-inkar601 jupyter-inkar601  4096 Apr  4 10:46 homework1
# drwxr-xr-x 7 jupyter-inkar601 jupyter-inkar601  4096 Apr  4 11:14 homework3
# drwxr-xr-x 3 jupyter-inkar601 jupyter-inkar601  4096 Mar 28 03:17 inkar
# -rw-r--r-- 1 jupyter-inkar601 jupyter-inkar601 21014 Apr  9 15:56 inkar_hw4.ipynb
# -rw-r--r-- 1 jupyter-inkar601 jupyter-inkar601  8561 Mar 28 12:15 Inkar.ipynb
# -rw-r--r-- 1 jupyter-inkar601 jupyter-inkar601    12 Mar 28 00:55 inkar.txt
# -rw-r--r-- 1 jupyter-inkar601 jupyter-inkar601    54 Mar 28 14:09 octave-workspace
# ...

# %%
# egrep

# %%
cat river.txt
# Out:
# Nil   6650
# Amazon   6515
# Yangtze   6300
# Mississippi   6275
# Yenisei   5539
# Yellow River   5464
# Ob-Irtysh   5410
# Rio de la Plata   4880
# Congo   4700
# Amur   4444
# Lena   4400
# Mekong   4350
# Mackenzie   4241
# Niger   4200
# Brahmaputra   3848
# Murray   3672
# Volga   3645
# Madeira   3380
# Purus   3211
# Yukon   3185
# Sao Francisco   3180
# Syr Darya   3078
# Salween   3060

# %%
egrep 'M' river.txt
# Out:
# Mississippi   6275
# Mekong   4350
# Mackenzie   4241
# Murray   3672
# Madeira   3380

# %%
egrep '*r' river.txt
# Out:
# Yellow River   5464
# Ob-Irtysh   5410
# Amur   4444
# Niger   4200
# Brahmaputra   3848
# Murray   3672
# Madeira   3380
# Purus   3211
# Sao Francisco   3180
# Syr Darya   3078

# %%
egrep '6' river.txt
# Out:
# Nil   6650
# Amazon   6515
# Yangtze   6300
# Mississippi   6275
# Yellow River   5464
# Murray   3672
# Volga   3645
# Salween   3060

# %%
egrep 'S' river.txt
# Out:
# Sao Francisco   3180
# Syr Darya   3078
# Salween   3060

# %%
egrep 'Ye' river.txt
# Out:
# Yenisei   5539
# Yellow River   5464

# %%
egrep '*er' river.txt
# Out:
# Yellow River   5464
# Niger   4200

# %%
egrep 'er|Ye|51' river.txt
# Out:
# Amazon   6515
# Yenisei   5539
# Yellow River   5464
# Niger   4200

# %%
egrep [A-L] river.txt
# Out:
# Amazon   6515
# Ob-Irtysh   5410
# Congo   4700
# Amur   4444
# Lena   4400
# Brahmaputra   3848
# Sao Francisco   3180
# Syr Darya   3078

# %%
egrep '^Y' river.txt
# Out:
# Yangtze   6300
# Yenisei   5539
# Yellow River   5464
# Yukon   3185

# %%
man egrep
# Out:
# GREP(1)                          User Commands                         GREP(1)
#
# NAME
#        grep, egrep, fgrep, rgrep - print lines matching a pattern
#
# SYNOPSIS
#        grep [OPTIONS] PATTERN [FILE...]
#        grep [OPTIONS] -e PATTERN ... [FILE...]
#        grep [OPTIONS] -f FILE ... [FILE...]
#
# DESCRIPTION
#        grep  searches  for  PATTERN  in  each  FILE.  A FILE of “-” stands for
#        standard input.  If no FILE is given, recursive  searches  examine  the
#        working  directory,  and nonrecursive searches read standard input.  By
#        default, grep prints the matching lines.
#
#        In addition, the variant programs egrep, fgrep and rgrep are  the  same
#        as  grep -E,  grep -F,  and  grep -r, respectively.  These variants are
#        deprecated, but are provided for backward compatibility.
#
# OPTIONS
#    Generic Program Information
#        --help Output a usage message and exit.
#
#        -V, --version
# ...

# %%
date
# Out:
# Sat Apr 11 02:33:25 UTC 2020
